# %%
import os
import pathlib
import numpy as np
import csv
from collections import Counter
import random
import matplotlib.pyplot as plt

# %%
def read_annotation(filename):
    events = []
    with open(filename, 'r') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        for row in spamreader:
            events.append(row)
    return events

# %%
events = read_annotation("eq_contributions.csv")
len(events)
# Out:
# 1596

# %%
words_list = [e[0].lower() for e in events[1:] if e[1] == "English"]
len(words_list)
# Out:
# 918

# %%
hq_words = ["bright","brittle","clear","crisp","harsh","hollow","sharp","shrill","tinny","woody","big","boom","boxy","dark","dull","fat","full","muddy","muffled","punch","smooth","sweet","warm","flat",
            "crunchy","deep","soothing","clean","airy","cold","metallic","booming"]

len(hq_words)
# Out:
# 32

# %%
words_list[0:10]
# Out:
# ['hot',
#  'wet',
#  'slow',
#  'saucy',
#  'heavy',
#  'shrill',
#  'warm',
#  'chill',
#  'sharp',
#  'corn']

# %%
high_rated_words = list(set([e[0].lower() for e in events[1:] if e[1] == "English" and float(e[3]) > 0.7 and e[0].lower() not in hq_words]))
high_rated_words.sort()

# %%
high_rated_words
# Out:
# ['aggressive',
#  'baseball',
#  'beautiful',
#  'biting',
#  'bold',
#  'brash',
#  'brass',
#  'brassy',
#  'breezy',
#  'calm',
#  'caring',
#  'cheerful',
#  'clarity',
#  'cooing',
#  'cool',
#  'cute',
#  'disgusting',
#  'down',
#  'edge',
#  'edgy',
#  'enchanting',
#  'energetic',
#  'energizing',
#  'excited',
#  'exciting',
#  'fancy',
#  'fluffy',
#  'forceful',
#  'frigid',
#  'funky',
#  'genius',
#  'gentle',
#  'good',
#  'gruff',
#  'happy',
#  'hard',
#  'heart-warming',
#  'heat',
#  'heavy',
#  'hot',
#  'huge',
#  'icy',
#  'jagged',
#  'large',
#  'light',
#  'loud',
#  'love',
#  'low',
#  'mellow',
#  'mournful',
#  'noisy',
#  'passionate',
#  'peace',
#  'peaceful',
#  'pleasing',
#  'pleasurable',
#  'plodding',
#  'poor',
#  'punchy',
#  'quiet',
#  'radiant',
#  'relaxing',
#  'reserved',
#  'rich',
#  'romantic',
#  'rousing',
#  'rumble',
#  'serene',
#  'sloppy',
#  'slow',
#  'soft',
#  'solemn',
#  'splash',
#  'squeaking',
#  'strong',
#  'taco',
#  'techno',
#  'tense',
#  'throbbing',
#  'thumpy',
#  'thunderous',
#  'twangy',
#  'velvety',
#  'whispered',
#  'whispering',
#  'wistful']

# %%
len(high_rated_words)
# Out:
# 86

# %%
cc = dict(Counter(words_list))
words_set = list(cc.keys())
words_set.sort()

# %%
len(words_set)
# Out:
# 388

# %%
cc
# Out:
# {'hot': 8,
#  'wet': 2,
#  'slow': 2,
#  'saucy': 1,
#  'heavy': 15,
#  'shrill': 4,
#  'warm': 64,
#  'chill': 1,
#  'sharp': 8,
#  'corn': 1,
#  'soft': 29,
#  'apple': 1,
#  'deep': 6,
#  'scary': 5,
#  'oxygen': 1,
#  'tinny': 8,
#  'loud': 26,
#  'flat': 3,
#  'jarring': 3,
#  'prickly': 1,
#  'crunchy': 5,
#  'excitement': 1,
#  'cold': 34,
#  'cool': 14,
#  'relaxing': 4,
#  'hard': 10,
#  'light': 6,
#  'funky': 4,
#  'bright': 19,
#  'fast': 5,
#  'crisp': 8,
#  'pretty': 2,
#  'hollow': 3,
#  'steep': 1,
#  'classic': 2,
#  'mellow': 8,
#  'dark': 8,
#  'tight': 1,
#  'boom': 1,
#  'sad': 9,
#  'sunshine': 1,
#  'fuzzy': 1,
#  'carefree': 1,
#  'woody': 1,
#  'crunch': 1,
#  'sweet': 5,
#  'mournful': 1,
#  'ralph': 1,
#  'groovy': 1,
#  'soothing': 17,
#  'happy': 22,
#  'damp': 1,
#  'tiger': 1,
#  'greasy': 1,
#  'clear': 12,
#  'pleasant': 6,
#  'cheerful': 3,
#  'creepy': 1,
#  'nice': 3,
#  'punch': 1,
#  'delightful': 1,
#  'balanced': 1,
#  'car': 1,
#  'gradual': 1,
#  'calm': 13,
#  'pleasing': 2,
#  'love': 4,
#  'metallic': 2,
#  'cat': 2,
#  'biting': 1,
#  'serene': 3,
#  'fast-paced': 1,
#  'smooth': 14,
#  'peaceful': 7,
#  'please': 1,
#  'upbeat': 3,
#  'hello': 3,
#  'clash': 1,
#  'romantic': 4,
#  'dry': 2,
#  'breezy': 1,
#  'mysterious': 1,
#  'man': 1,
#  'surprised': 1,
#  'invigorate': 1,
#  'throbbing': 2,
#  'fire': 1,
#  'morning': 2,
#  'big': 1,
#  'chunky': 2,
#  'somber': 1,
#  'dull': 3,
#  'whispered': 1,
#  'reserved': 1,
#  'beautiful': 10,
#  'rock': 4,
#  'brash': 1,
#  'metal': 1,
#  'humid': 1,
#  'rage': 1,
#  'harsh': 16,
#  'good': 3,
#  'muffled': 6,
#  'grand': 2,
#  'graceful': 2,
#  'evil': 1,
#  'caustic': 1,
#  'vague': 1,
#  'forceful': 1,
#  'heart-warming': 1,
#  'distant': 2,
#  'melodious': 3,
#  'martial': 1,
#  'joy': 1,
#  'enthusiastic': 1,
#  'great': 1,
#  'super': 2,
#  'mother': 1,
#  'huge': 1,
#  'meaty': 1,
#  'cute': 1,
#  'noisy': 6,
#  'fun': 4,
#  'melodic': 4,
#  'brave': 1,
#  'icy': 1,
#  'annoying': 1,
#  'powerful': 2,
#  'kind': 1,
#  'vintage': 1,
#  'edge': 1,
#  'bassy': 1,
#  'quiet': 5,
#  'awesome': 2,
#  'quick': 1,
#  'passionate': 1,
#  'smart': 1,
#  'grainy': 2,
#  'tropical': 1,
#  'harmonious': 1,
#  'guitar': 1,
#  'high-pitched': 2,
#  'sincere': 1,
#  'thumpy': 1,
#  'gentle': 8,
#  'archaic': 1,
#  'even': 1,
#  'tremble': 1,
#  'vicious': 1,
#  'clean': 4,
#  'euphoric': 1,
#  'alluring': 1,
#  'caring': 1,
#  'roar': 2,
#  'charming': 1,
#  'wild': 2,
#  'mean': 1,
#  'power': 2,
#  'airy': 3,
#  'music': 1,
#  'exciting': 3,
#  'distracting': 1,
#  'rigid': 1,
#  'muddy': 2,
#  'dramatic': 1,
#  'dangerous': 1,
#  'pop': 1,
#  'cheery': 1,
#  'brass': 1,
#  'sinister': 1,
#  'fleeting': 1,
#  'grieving': 1,
#  'important': 1,
#  'eager': 1,
#  'grating': 1,
#  'low': 2,
#  'computer': 1,
#  'sluggish': 1,
#  'depressed': 1,
#  'whispering': 1,
#  'excited': 3,
#  'famous': 1,
#  'rain': 1,
#  'playful': 1,
#  'screeching': 1,
#  'angry': 2,
#  'joyful': 1,
#  'helpful': 1,
#  'full': 2,
#  'worried': 1,
#  'uplifting': 4,
#  'blast': 1,
#  'large': 2,
#  'sloppy': 1,
#  'buzz': 2,
#  'strong': 2,
#  'twangy': 1,
#  'riotous': 1,
#  'bold': 2,
#  'elegant': 3,
#  'moody': 1,
#  'rousing': 1,
#  'rich': 4,
#  'easy': 1,
#  'small': 1,
#  'aggravating': 2,
#  'joyous': 2,
#  'tense': 2,
#  'tender': 1,
#  'energizing': 1,
#  'brittle': 1,
#  'muddled': 1,
#  'watery': 1,
#  'lively': 1,
#  'foggy': 1,
#  'solid': 1,
#  'fat': 2,
#  'boxy': 1,
#  'chilly': 1,
#  'dog': 1,
#  'obnoxious': 1,
#  'safe': 1,
#  'lightening': 1,
#  'taco': 1,
#  'tragic': 1,
#  'clarity': 1,
#  'cow': 1,
#  'grandiose': 1,
#  'agitated': 1,
#  'raspy': 3,
#  'forgetful': 1,
#  'toasty': 1,
#  'thunderous': 1,
#  'disgusting': 1,
#  'spine-tingling': 1,
#  'melody': 1,
#  'sadness': 1,
#  'wow': 1,
#  'cooing': 1,
#  'welcome': 2,
#  'impatient': 1,
#  'vibrant': 1,
#  'fiery': 1,
#  'wise': 1,
#  'smelly': 1,
#  'epic': 1,
#  'rumble': 2,
#  'mischievous': 2,
#  'floating': 1,
#  'drums': 1,
#  'wistful': 2,
#  'noise': 1,
#  'enchanting': 3,
#  'blaring': 1,
#  'serious': 1,
#  'darkness': 1,
#  'energetic': 5,
#  'bear': 1,
#  'intelligent': 1,
#  'deafening': 1,
#  'dreamy': 1,
#  'fresh': 2,
#  'sound': 1,
#  'lazy': 1,
#  'jagged': 1,
#  'energized': 1,
#  'infernal': 1,
#  'aggressive': 4,
#  'pleasurable': 1,
#  'youthful': 1,
#  'ecstasy': 1,
#  'techno': 1,
#  'delicious': 1,
#  'discombobulated': 1,
#  'honest': 1,
#  'tough': 2,
#  'plodding': 1,
#  'god': 1,
#  'victorious': 1,
#  'hate': 3,
#  'bang': 1,
#  'jumpy': 1,
#  'punchy': 2,
#  'nasty': 1,
#  'pure': 1,
#  'trimble': 1,
#  'solemn': 1,
#  'gruff': 1,
#  'enticing': 1,
#  'emotional': 3,
#  'subtle': 1,
#  'drive': 1,
#  'pumping': 1,
#  'spooky': 1,
#  'little': 1,
#  'sensual': 1,
#  'fluffy': 1,
#  'brassy': 2,
#  'frightening': 1,
#  'melancholy': 1,
#  'radiant': 1,
#  'cerebral': 1,
#  'squeaking': 1,
#  'humble': 1,
#  'sprightly': 1,
#  'genius': 1,
#  'scared': 1,
#  'down': 1,
#  'bonito': 1,
#  'harmony': 1,
#  'thick': 1,
#  'crackling': 1,
#  'disgusted': 1,
#  'optimistic': 1,
#  'pessimistic': 1,
#  'anticipation': 1,
#  'tranquil': 1,
#  'crash': 1,
#  'cosy': 1,
#  'severe': 1,
#  'splash': 1,
#  'moan': 1,
#  'game dog': 1,
#  'bored': 1,
#  'food': 2,
#  'inspirational': 1,
#  'painful': 1,
#  'hardness': 1,
#  'brillante': 1,
#  'jazzy': 1,
#  'high': 2,
#  'motive': 1,
#  'congested': 1,
#  'booming': 1,
#  'roll': 1,
#  'relaxed': 1,
#  'frosty': 1,
#  'poor': 1,
#  'lindo': 1,
#  'spacey': 1,
#  'violent': 1,
#  'dynamic': 1,
#  'favourable': 1,
#  'ominous': 1,
#  'frantic': 1,
#  'radical': 1,
#  'power-puff': 1,
#  'choppy': 1,
#  'workout': 1,
#  'shock': 1,
#  'fool': 1,
#  'frigid': 1,
#  'rough': 1,
#  'stormy': 1,
#  'grace': 1,
#  'splendid': 1,
#  'scratchy': 1,
#  'velvety': 1,
#  'coarse': 1,
#  'bag': 1,
#  'sea': 1,
#  'muscle': 1,
#  'awkward': 1,
#  'aidan': 1,
#  'confident': 1,
#  'frustration': 1,
#  'heat': 1,
#  'winter': 1,
#  'anger': 1,
#  'peace': 1,
#  'rhythmic': 1,
#  'children': 1,
#  'bouncy': 1,
#  'boisterous': 1,
#  'classy': 1,
#  'edgy': 1,
#  'marvellous': 1,
#  'fancy': 1,
#  'placid': 1,
#  'cricket': 1,
#  'scabrous': 1,
#  'baseball': 1,
#  'saccharine': 1,
#  'table tennis': 1,
#  'snowball': 1,
#  'flow': 1,
#  'hero': 1,
#  'good morning': 1}

# %%
import csv
import matplotlib.pyplot as plt
import numpy as np
import random

# 你的 HQwords 列表
hq_words = [
    "bright","brittle","clear","crisp","harsh","hollow","sharp","shrill","tinny","woody",
    "big","boom","boxy","dark","dull","fat","full","muddy","muffled","punch","smooth",
    "sweet","warm","flat","crunchy","deep","soothing","clean","airy","cold","metallic","booming"
]

hq_words9 = random.sample(hq_words, 9)

def load_eq_data(filename):
    """
    读取 CSV 文件，解析出：
      1) freq_list：从列名中提取的频率（对数绘图用）
      2) eq_curves：dict，key=descriptor(小写)，value=对应增益数组
    """
    with open(filename, 'r', encoding='utf-8') as f:
        reader = csv.reader(f)
        header = next(reader)  # 读表头
        
        # 假设前三列分别是：descriptor, audio_id, ratings_consistency
        # 从第4列开始，每列名形如 "RSC_20Hz_band"
        freq_cols = header[3:]
        
        # 从列名中提取对应的数值频率
        freq_list = []
        for col_name in freq_cols:
            # 例如 col_name = "RSC_20Hz_band"
            # 去掉 "RSC_" 和 "_band"
            # 再去掉 "Hz" 部分
            # 最终得到数字 20
            # 注意有些频段可能不是整数频率（例如 12.5Hz_band），可用 float
            tmp = col_name.replace("RSC_", "").replace("_band", "").replace("Hz", "")
            freq_value = float(tmp)  # 有小数的情况就用 float，否则 int 也行
            freq_list.append(freq_value)
        
        eq_curves = {}
        for row in reader:
            if not row:
                continue
            
            descriptor = row[0].lower().strip()
            # row[1], row[2] 分别是 audio_id 和 ratings_consistency，可根据需求处理或忽略
            
            # 从第4列开始是增益数据
            gains_str = row[3:-1]
            try:
                gains = [float(g) for g in gains_str]
            except ValueError:
                # 如果有无法转换为浮点数的情况，可以选择跳过或做其他处理
                continue
            
            eq_curves[descriptor] = gains
        
        return freq_list, eq_curves


# 假设你的 CSV 文件名是 "eq_contributions.csv"
csv_file = "eq_contributions.csv"
freq_list, eq_curves = load_eq_data(csv_file)

# 现在 freq_list 就是 [20.0, 50.0, 80.0, 120.0, 160.0, ...]
# eq_curves 是一个 dict，形如：
# {
#   "bright": [g1, g2, g3, ...],
#   "warm":   [g1, g2, g3, ...],
#   ...
# }

# 可以先检查一下 freq_list 的长度
print("频段数量:", len(freq_list))
print("示例频率列表:", freq_list)


# 准备子图 3×3
fig, axs = plt.subplots(3, 3, figsize=(12, 8), sharex=True, sharey = True)
fig.suptitle("HQ Words EQ Curves", fontsize=16)

# 确保只拿前 9 个词（如果你 hq_words9 超过 9 个）
words_to_plot = hq_words9[:9]

for i, word in enumerate(words_to_plot):
    row = i // 3
    col = i % 3
    ax = axs[row, col]

    w_lower = word.lower()
    if w_lower in eq_curves:
        gains = eq_curves[w_lower]
        # 绘制单个子图
        ax.plot(freq_list, gains, label=word)
        ax.set_title(word)
    else:
        ax.set_title(f"{word}\n(No data)")

    # 设置对数刻度
    ax.set_xscale('log')
    ax.set_xlim(20, 22000)
    #可以只在最下方和最左边的子图设置 label，避免重复
    if row == 2:
        ax.set_xlabel("Frequency (Hz)")
    if col == 0:
        ax.set_ylabel("Gain (dB)")

    # 设置自定义的 x 轴刻度：在对数空间均匀分布，标签显示为线性数值
    low, high = 20, 22000
    num_ticks = 6  # 刻度个数，分成 5 段
    ticks_log = np.linspace(np.log10(low), np.log10(high), num_ticks)
    ticks = 10 ** ticks_log
    tick_labels = [f"{int(round(t))}" for t in ticks]
    ax.set_xticks(ticks)
    ax.set_xticklabels(tick_labels)
    ax.tick_params(labelbottom=True)
    ax.tick_params(labelleft = True)
    ax.axhline(y=0, color='pink', linewidth=1.3)

# 如果想要统一的网格，可以在每个子图中加 grid
for ax_row in axs:
    for ax in ax_row:
        ax.grid(True, which='both', ls='--', lw=0.5)

plt.tight_layout(rect=[0, 0, 1, 0.96])  # 给 suptitle 留空间
plt.show()
# Out:
# 频段数量: 40
# 示例频率列表: [20.0, 50.0, 83.0, 120.0, 161.0, 208.0, 259.0, 318.0, 383.0, 455.0, 537.0, 628.0, 729.0, 843.0, 971.0, 1114.0, 1273.0, 1452.0, 1652.0, 1875.0, 2126.0, 2406.0, 2719.0, 3070.0, 3462.0, 3901.0, 4392.0, 4941.0, 5556.0, 6244.0, 7014.0, 7875.0, 8839.0, 9917.0, 11124.0, 12474.0, 13984.0, 15675.0, 17566.0, 19682.0]
